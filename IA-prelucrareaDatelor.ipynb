# %%
#sub1
import csv
myList = []
with open(r'C:\Users\laura\iris1.csv') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    for row in readCSV:
        if len(row) == 5:
            myList.append([float(row[0]), float(row[1]), float(row[2]), float(row[3])])
#print(myList)
#sub2
import numpy as np
npArray = np.array(myList)

print('Pentru coloana 0:')
col0_min = np.min(npArray[:,0])
print('Valoarea minima de pe coloana 0 este', col0_min)
col0_max = np.max(npArray[:,0])
print('Valoarea maxima de pe coloana 0 este:', col0_max)
col0_medie = np.average(npArray[:,0])
print('Valoarea medie de pe coloana 0 este:', col0_medie)
col0_mediana = np.median(npArray[:,0])
print('Valoarea mediana de pe coloana 0 este:', col0_mediana)

print('Pentru coloana 1:')
col1_min = np.min(npArray[:,0])
print('Valoarea minima de pe coloana 1 este', col1_min)
col1_max = np.max(npArray[:,0])
print('Valoarea maxima de pe coloana 1 este:', col1_max)
col1_medie = np.average(npArray[:,0])
print('Valoarea medie de pe coloana 1 este:', col1_medie)
col1_mediana = np.median(npArray[:,0])
print('Valoarea mediana de pe coloana 1 este:', col1_mediana)

print('Pentru coloana 2:')
col2_min = np.min(npArray[:,0])
print('Valoarea minima de pe coloana 2 este', col2_min)
col2_max = np.max(npArray[:,0])
print('Valoarea maxima de pe coloana 2 este:', col2_max)
col2_medie = np.average(npArray[:,0])
print('Valoarea medie de pe coloana 2 este:', col2_medie)
col2_mediana = np.median(npArray[:,0])
print('Valoarea mediana de pe coloana 2 este:', col2_mediana)

print('Pentru coloana 3:')
col3_min = np.min(npArray[:,0])
print('Valoarea minima de pe coloana 3 este', col3_min)
col3_max = np.max(npArray[:,0])
print('Valoarea maxima de pe coloana 3 este:', col3_max)
col3_medie = np.average(npArray[:,0])
print('Valoarea medie de pe coloana 3 este:', col3_medie)
col3_mediana = np.median(npArray[:,0])
print('Valoarea mediana de pe coloana 3 este:', col3_mediana)

#sub3
col0_norm = (npArray[:,0]-min(npArray[:,0])) / (max(npArray[:,0]) - min(npArray[:,0]))
print('\n',col0_norm)

col1_norm = (npArray[:,0]-min(npArray[:,0])) / (max(npArray[:,0]) - min(npArray[:,0]))
print('\n',col1_norm)

col2_norm = (npArray[:,0]-min(npArray[:,0])) / (max(npArray[:,0]) - min(npArray[:,0]))
print('\n',col2_norm)

col3_norm = (npArray[:,0]-min(npArray[:,0])) / (max(npArray[:,0]) - min(npArray[:,0]))
print('\n',col3_norm)
# Out:
# Pentru coloana 0:
# Valoarea minima de pe coloana 0 este 4.3
# Valoarea maxima de pe coloana 0 este: 7.9
# Valoarea medie de pe coloana 0 este: 5.843333333333334
# Valoarea mediana de pe coloana 0 este: 5.8
# Pentru coloana 1:
# Valoarea minima de pe coloana 1 este 4.3
# Valoarea maxima de pe coloana 1 este: 7.9
# Valoarea medie de pe coloana 1 este: 5.843333333333334
# Valoarea mediana de pe coloana 1 este: 5.8
# Pentru coloana 2:
# Valoarea minima de pe coloana 2 este 4.3
# Valoarea maxima de pe coloana 2 este: 7.9
# Valoarea medie de pe coloana 2 este: 5.843333333333334
# Valoarea mediana de pe coloana 2 este: 5.8
# Pentru coloana 3:
# Valoarea minima de pe coloana 3 este 4.3
# Valoarea maxima de pe coloana 3 este: 7.9
# Valoarea medie de pe coloana 3 este: 5.843333333333334
# Valoarea mediana de pe coloana 3 este: 5.8
#
#  [0.22222222 0.16666667 0.11111111 0.08333333 0.19444444 0.30555556
#  0.08333333 0.19444444 0.02777778 0.16666667 0.30555556 0.13888889
# ...

# %%
#sub4
import csv
myList = []
with open(r'iris1.csv') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    for row in readCSV:
        if len(row) == 5:
            myVar = float(row[0])*0.2 + float(row[1])*1.1 + float(row[2])*(-0.9) + float(row[3]);
            myList.append([float(row[0]), float(row[1]), float(row[2]), float(row[3]), float(myVar)])

import numpy as np
npArray = np.array(myList)

#print(myList)


filename = 'irisOut.csv'

with open(filename, "w") as f:
    for sublist in myList:
        line = "{}, {}, {}, {}, {}\n".format(sublist[0], sublist[1],sublist[2],sublist[3],sublist[4])
        f.write(line)
